# %%
import nltk, os, subprocess, code, glob, re, traceback, sys, inspect
# from time import clock, sleep
from tika import parser
import re

# filename = input('Enter the path to the resume: ')

filename = 'resume3.pdf'

parsed_pdf = parser.from_file(filename)

data = parsed_pdf['content']

res = re.sub('\s\s+', ' ', data)

data1 = str(res)

file1 = open("rawdata.txt","w",encoding="utf-8")
file1.write(data1)
file1.close()

data = str(data.strip())

p = ""
f = False

for ch in data:
    if ch == '\n':
        f = True
    else:
        if f == True:
            f = False
            p = p + '\n'
        p = p + ch

data = str(p)

p = ""
f = False

for ch in data:
    if ch == ' ':
        f = True
    else:
        if f == True:
            f = False
            p = p + ' '
        p = p + ch

data = str(p)
file1 = open("data.txt","w",encoding="utf-8")
file1.write(data)
file1.close()

#open text file in read mode
text_file = open("data.txt", "rb")

#read whole file to a string
data = text_file.read()


#close file
text_file.close()
data
# Out:
# b'Mobile: 09876543210 \r\nPhone: 044-12345678 \r\nEmail: aniljain@gmail.com \r\nANIL JAIN \r\n \r\nCareer objective \r\n \r\n To have a growth oriented and challenging career, where I can contribute my knowledge and \r\nskills to the organization and enhance my experience through continuous learning and teamwork. \r\n \r\n \r\nAcademic Qualification \r\n \r\n \r\nWork Experience \r\n \r\nJuly2012\xe2\x80\x93 Dec2012 (6months) Works as a junior production engineer inYONGSAN \r\nAUTOMOTIVE INDIA PVT LTD, Papparampakkam \r\n \r\nSoftware proficiency \r\n \r\n\xef\x82\xb7 Software known: Auto Cad, SolidWorks, Ansys, Automation Studio. \r\n\xef\x82\xb7 Office suite: MS-office. \r\n \r\nArea of Interest \r\n \r\n\xef\x82\xb7 Manufacturing Technology \r\n\xef\x82\xb7 Automobile Engineering \r\n \r\n \r\nMini Project \r\nCourse University/Board Institute \r\nYear of \r\npassing \r\nPercentage/CGPA \r\nB.E- \r\nMechanical \r\nEngineering \r\nAnnaUniversity \r\nSri Muthukumaran \r\nInstitute of Higher \r\nTechnology \r\n2012 7.44(cgpa) \r\nHigher \r\nSecondary \r\nMatric \r\nNav Bharath \r\nVidyalaya \r\nMat.Hr.Sec.School, \r\nMangadu \r\n2008 76.58 \r\nSSLC Matric \r\nNav Bharath \r\nVidyalaya \r\nMat.Hr.Sec.School, \r\nMangadu \r\n2006 79.9 \r\n \r\n\xef\x82\xb7 Project Area : Manufacturing Technology \r\n\xef\x82\xb7 Project Title : \xe2\x80\x9cDesign and fabrication of Reciprocating Saw\xe2\x80\x9d \r\n\xef\x82\xb7 Project Role : Team leader \r\n\xef\x82\xb7 Software used for Designing: SolidWorks 2005 \r\n \r\nMain Project \r\n\xef\x82\xb7 Project Area : Design of Transmission system. \r\n\xef\x82\xb7 Project Title : \xe2\x80\x9cDesign, Analysis and fabrication of Modular \r\nStair \r\n Case Climber\xe2\x80\x9d \r\n\xef\x82\xb7 Project Role : Done the Analysis and helped in fabrication. \r\n\xef\x82\xb7 Software used for Designing: Solid Works-2010. \r\n\xef\x82\xb7 Software used for Analyzing: Ansys 11 \r\n \r\nIndustrial visits \r\n \r\n\xef\x82\xb7 Integral Coach Factory(ICF), Chennai \r\n\xef\x82\xb7 Karnataka Turned Components, Hosur \r\n \r\n Training and Workshops undergone \r\n \r\nImplant training: \r\n\xef\x82\xb7 Organization : Integral Coach Factory (ICF), Perumbur, Chennai-600 038. \r\n\xef\x82\xb7 Duration : 7 days \r\n\xef\x82\xb7 Knowledge Gained : Learnt about various machining processes \r\n \r\nWork shop: \r\n \r\n\xef\x82\xb7 Robotics: \r\nPlace: college campus \r\nPeriod and Time: 21-24th Jan 2011. \r\n \r\n Papers presented \r\n \r\n\xef\x82\xb7 Presented a Paper on \xe2\x80\x9cPower Production Through Bladeless Turbine.\xe2\x80\x9d at Misrimal Navajee \r\nMunoth Jain Engineering College \r\n \r\nAchievements and Extra-curricular activities \r\n \r\n\xef\x82\xb7 Participated and won prizes in English essay competition at school level. \r\n\xef\x82\xb7 Participated and won prizes in drawing competition conducted by Road safety Educational & \r\nResearch Service Society - at school level. \r\n\xef\x82\xb7 Active participant of NSS and Active blood donor. \r\n \r\nPersonal Trait \r\n \r\n\xef\x82\xb7 Creative and logical \r\n\xef\x82\xb7 Problem solving ability \r\n\xef\x82\xb7 Co-operative and keen observer \r\n \r\nHobbies \r\n\xef\x82\xb7 Gardening \r\n\xef\x82\xb7 Playing Volleyball \r\n \r\nPersonal Profile \r\nDate of Birth : 12.11.1992 \r\nGender : Male \r\nMarital status : Single \r\nLanguages Known : Tamil, English and Hindi (Read and Write) \r\nPermanent Address : 10/1 N S Road, Marina Lane, Chennai-600010 \r\n \r\n \r\nI hereby declare that all the details furnished here are true to the best of my knowledge. \r\n \r\nDATE : NAME : ANIL JAIN \r\n \r\nPLACE: SIGNATURE:'

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convertPDFToText(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)
    fp.close()
    device.close()
    string = retstr.getvalue()
    retstr.close()
    return string

def preprocess(document):
    '''
    Information Extraction: Preprocess a document with the necessary POS tagging.
    Returns three lists, one with tokens, one with POS tagged lines, one with POS tagged sentences.
    Modules required: nltk
    '''
    try:
        # Try to get rid of special characters
        try:
            document = document.decode('ascii', 'ignore')
        except:
            document = document.encode('ascii', 'ignore')
        # Newlines are one element of structure in the data
        # Helps limit the context and breaks up the data as is intended in resumes - i.e., into points
        lines = [el.strip() for el in document.split("\n") if len(el) > 0]  # Splitting on the basis of newlines 
        lines = [nltk.word_tokenize(el) for el in lines]    # Tokenize the individual lines
        lines = [nltk.pos_tag(el) for el in lines]  # Tag them
        # Below approach is slightly different because it splits sentences not just on the basis of newlines, but also full stops 
        # - (barring abbreviations etc.)
        # But it fails miserably at predicting names, so currently using it only for tokenization of the whole document
        sentences = nltk.sent_tokenize(document)    # Split/Tokenize into sentences (List of strings)
        sentences = [nltk.word_tokenize(sent) for sent in sentences]    # Split/Tokenize sentences into words (List of lists of strings)
        tokens = sentences
        sentences = [nltk.pos_tag(sent) for sent in sentences]    # Tag the tokens - list of lists of tuples - each tuple is (<word>, <tag>)
        # Next 4 lines convert tokens from a list of list of strings to a list of strings; basically stitches them together
        dummy = []
        for el in tokens:
            dummy += el
        tokens = dummy
        # tokens - words extracted from the doc, lines - split only based on newlines (may have more than one sentence)
        # sentences - split on the basis of rules of grammar
        return tokens, lines, sentences
    except Exception as e:
        print(e)

data = convertPDFToText(filename)
file1 = open("data.txt","w",encoding="utf-8")
file1.write(data)
file1.close()

#open text file in read mode
text_file = open("data.txt", "rb")

#read whole file to a string
data = text_file.read()


#close file
text_file.close()
print(data)
        
# tokenize
try:
    [tokens, lines, sentences] = preprocess(data)
except Exception as e:
    e
# Out:
# b'Mobile: 09876543210 \r\nPhone: 044-12345678 \r\nEmail:  aniljain@gmail.com \r\n\r\nANIL JAIN \r\n \r\nCareer objective \r\n \r\n     To have a growth oriented and challenging career, where I can contribute my knowledge and \r\nskills to the organization and enhance my experience through continuous learning and teamwork. \r\n \r\n \r\nAcademic Qualification \r\n\r\nCourse \r\n\r\nUniversity/Board \r\n\r\nInstitute \r\n\r\nYear of \r\npassing \r\n\r\nPercentage/CGPA \r\n\r\nB.E- \r\n\r\nMechanical \r\nEngineering \r\n\r\nAnnaUniversity \r\n\r\nHigher \r\n\r\nSecondary \r\n\r\nMatric \r\n\r\nSSLC \r\n\r\nMatric \r\n\r\n \r\n \r\nWork Experience \r\n \r\n\r\nSri Muthukumaran \r\nInstitute of Higher \r\n\r\nTechnology \r\n\r\nNav Bharath \r\nVidyalaya  \r\n\r\nMat.Hr.Sec.School, \r\n\r\nMangadu \r\n\r\nNav Bharath \r\nVidyalaya  \r\n\r\nMat.Hr.Sec.School, \r\n\r\nMangadu \r\n\r\n2012 \r\n\r\n7.44(cgpa) \r\n\r\n2008 \r\n\r\n76.58 \r\n\r\n2006 \r\n\r\n79.9 \r\n\r\nJuly2012\xe2\x80\x93  Dec2012  (6months)  Works  as  a  junior  production  engineer  inYONGSAN \r\n\r\nAUTOMOTIVE INDIA PVT LTD, Papparampakkam \r\n \r\nSoftware proficiency \r\n \r\n\r\n\xef\x82\xb7          Software known: Auto Cad, SolidWorks, Ansys, Automation Studio.   \r\n\xef\x82\xb7         Office suite: MS-office. \r\n\r\n \r\nArea of Interest \r\n \r\n\r\n\xef\x82\xb7         Manufacturing Technology \r\n\xef\x82\xb7         Automobile Engineering \r\n\r\n \r\n \r\nMini Project \r\n\r\n\x0c \r\n\r\n\xef\x82\xb7         Project Area                         : Manufacturing Technology \r\n\xef\x82\xb7         Project Title                         : \xe2\x80\x9cDesign and fabrication of Reciprocating Saw\xe2\x80\x9d \r\n\xef\x82\xb7         Project  Role                          : Team leader \r\n\xef\x82\xb7         Software used for Designing: SolidWorks 2005 \r\n\r\n \r\nMain Project \r\n\r\n\xef\x82\xb7         Project Area                           :   Design of Transmission system. \r\n\xef\x82\xb7         Project Title                           :  \xe2\x80\x9cDesign, Analysis and fabrication of Modular \r\n\r\nStair                     \r\n         Case Climber\xe2\x80\x9d \r\n\r\n\xef\x82\xb7         Project Role                           :  Done the Analysis and helped in fabrication. \r\n\xef\x82\xb7         Software used for Designing:   Solid Works-2010. \r\n\xef\x82\xb7         Software used for Analyzing: Ansys 11 \r\n\r\n \r\nIndustrial visits \r\n \r\n\r\n\xef\x82\xb7         Integral Coach Factory(ICF), Chennai \r\n\xef\x82\xb7         Karnataka Turned Components, Hosur \r\n\r\n \r\n  Training and Workshops undergone \r\n \r\nImplant training: \r\n\r\n\xef\x82\xb7         Organization            : Integral Coach Factory (ICF), Perumbur, Chennai-600 038. \r\n\xef\x82\xb7         Duration                   : 7 days              \r\n\xef\x82\xb7          Knowledge Gained  : Learnt about various machining processes \r\n\r\n \r\nWork shop: \r\n \r\n\r\n\xef\x82\xb7         Robotics:   \r\n\r\nPlace: college campus \r\nPeriod and Time: 21-24th Jan 2011. \r\n \r\n  Papers presented \r\n \r\n\r\n\xef\x82\xb7  Presented a Paper on \xe2\x80\x9cPower Production Through Bladeless Turbine.\xe2\x80\x9d at Misrimal Navajee \r\n\r\nMunoth Jain Engineering College \r\n\r\n \r\nAchievements and Extra-curricular activities \r\n \r\n\r\n\xef\x82\xb7         Participated and won prizes in English essay competition at school level. \r\n\xef\x82\xb7         Participated  and  won  prizes  in  drawing  competition  conducted  by  Road  safety  Educational  & \r\n\r\nResearch Service Society - at school level. \r\n\r\n\xef\x82\xb7      Active participant of NSS and Active blood donor. \r\n\r\n \r\n\r\n\x0cPersonal Trait \r\n \r\n\r\n\xef\x82\xb7         Creative and logical \r\n\xef\x82\xb7         Problem solving ability \r\n\xef\x82\xb7         Co-operative and keen observer \r\n\r\n \r\nHobbies \r\n\r\n\xef\x82\xb7  Gardening \r\n\xef\x82\xb7  Playing Volleyball \r\n\r\ ...

# %%
tokens
# Out:
# ['Mobile',
#  ':',
#  '09876543210',
#  'Phone',
#  ':',
#  '044-12345678',
#  'Email',
#  ':',
#  'aniljain',
#  '@',
#  'gmail.com',
#  'ANIL',
#  'JAIN',
#  'Career',
#  'objective',
#  'To',
#  'have',
#  'a',
#  'growth',
#  'oriented',
#  'and',
#  'challenging',
#  'career',
#  ',',
#  'where',
#  'I',
#  'can',
#  'contribute',
#  'my',
#  'knowledge',
#  'and',
#  'skills',
#  'to',
#  'the',
#  'organization',
#  'and',
#  'enhance',
#  'my',
#  'experience',
#  'through',
#  'continuous',
#  'learning',
#  'and',
#  'teamwork',
#  '.',
#  'Academic',
#  'Qualification',
#  'Course',
#  'University/Board',
#  'Institute',
#  'Year',
#  'of',
#  'passing',
#  'Percentage/CGPA',
#  'B.E-',
#  'Mechanical',
#  'Engineering',
#  'AnnaUniversity',
#  'Higher',
#  'Secondary',
#  'Matric',
#  'SSLC',
#  'Matric',
#  'Work',
#  'Experience',
#  'Sri',
#  'Muthukumaran',
#  'Institute',
#  'of',
#  'Higher',
#  'Technology',
#  'Nav',
#  'Bharath',
#  'Vidyalaya',
#  'Mat.Hr.Sec.School',
#  ',',
#  'Mangadu',
#  'Nav',
#  'Bharath',
#  'Vidyalaya',
#  'Mat.Hr.Sec.School',
#  ',',
#  'Mangadu',
#  '2012',
#  '7.44',
#  '(',
#  'cgpa',
#  ')',
#  '2008',
#  '76.58',
#  '2006',
#  '79.9',
#  'July2012',
#  'Dec2012',
#  '(',
#  '6months',
#  ')',
#  'Works',
#  'as',
#  'a',
#  'junior',
#  'production',
#  'engineer',
#  'inYONGSAN',
#  'AUTOMOTIVE',
#  'INDIA',
#  'PVT',
#  'LTD',
#  ',',
#  'Papparampakkam',
#  'Software',
#  'proficiency',
#  'Software',
#  'known',
#  ':',
#  'Auto',
#  'Cad',
#  ',',
#  'SolidWorks',
#  ',',
#  'Ansys',
#  ',',
#  'Automation',
#  'Studio',
#  '.',
#  'Office',
#  'suite',
#  ':',
#  'MS-office',
#  '.',
#  'Area',
#  'of',
#  'Interest',
#  'Manufacturing',
#  'Technology',
#  'Automobile',
#  'Engineering',
#  'Mini',
#  'Project',
#  'Project',
#  'Area',
#  ':',
#  'Manufacturing',
#  'Technology',
#  'Project',
#  'Title',
#  ':',
#  'Design',
#  'and',
#  'fabrication',
#  'of',
#  'Reciprocating',
#  'Saw',
#  'Project',
#  'Role',
#  ':',
#  'Team',
#  'leader',
#  'Software',
#  'used',
#  'for',
#  'Designing',
#  ':',
#  'SolidWorks',
#  '2005',
#  'Main',
#  'Project',
#  'Project',
#  'Area',
#  ':',
#  'Design',
#  'of',
#  'Transmission',
#  'system',
#  '.',
#  'Project',
#  'Title',
#  ':',
#  'Design',
#  ',',
#  'Analysis',
#  'and',
#  'fabrication',
#  'of',
#  'Modular',
#  'Stair',
#  'Case',
#  'Climber',
#  'Project',
#  'Role',
#  ':',
#  'Done',
#  'the',
#  'Analysis',
#  'and',
#  'helped',
#  'in',
#  'fabrication',
#  '.',
#  'Software',
#  'used',
#  'for',
#  'Designing',
#  ':',
#  'Solid',
#  'Works-2010',
#  '.',
#  'Software',
#  'used',
#  'for',
#  'Analyzing',
#  ':',
#  'Ansys',
#  '11',
#  'Industrial',
#  'visits',
#  'Integral',
#  'Coach',
#  'Factory',
#  '(',
#  'ICF',
#  ')',
#  ',',
#  'Chennai',
#  'Karnataka',
#  'Turned',
#  'Components',
#  ',',
#  'Hosur',
#  'Training',
#  'and',
#  'Workshops',
#  'undergone',
#  'Implant',
#  'training',
#  ':',
#  'Organization',
#  ':',
#  'Integral',
#  'Coach',
#  'Factory',
#  '(',
#  'ICF',
#  ')',
#  ',',
#  'Perumbur',
#  ',',
#  'Chennai-600',
#  '038',
#  '.',
#  'Duration',
#  ':',
#  '7',
#  'days',
#  'Knowledge',
#  'Gained',
#  ':',
#  'Learnt',
#  'about',
#  'various',
#  'machining',
#  'processes',
#  'Work',
#  'shop',
#  ':',
#  'Robotics',
#  ':',
#  'Place',
#  ':',
#  'college',
#  'campus',
#  'Period',
#  'and',
#  'Time',
#  ':',
#  '21-24th',
#  'Jan',
#  '2011',
#  '.',
#  'Papers',
#  'presented',
#  'Presented',
#  'a',
#  'Paper',
#  'on',
#  'Power',
#  'Production',
#  'Through',
#  'Bladeless',
#  'Turbine',
#  '.',
#  'at',
#  'Misrimal',
#  'Navajee',
#  'Munoth',
#  'Jain',
#  'Engineering',
#  'College',
#  'Achievements',
#  'and',
#  'Extra-curricular',
#  'activities',
#  'Participated',
#  'and',
#  'won',
#  'prizes',
#  'in',
#  'English',
#  'essay',
#  'competition',
#  'at',
#  'school',
#  'level',
#  '.',
#  'Participated',
#  'and',
#  'won',
#  'prizes',
#  'in',
#  'drawing',
#  'competition',
#  'conducted',
#  'by',
#  'Road',
#  'safety',
#  'Educational',
#  '&',
#  'Research',
#  'Service',
#  'Society',
#  '-',
#  'at',
#  'school',
#  'level',
#  '.',
#  'Active',
#  'participant',
#  'of',
#  'NSS',
#  'and',
#  'Active',
#  'blood',
#  'donor',
#  '.',
#  'Personal',
#  'Trait',
#  'Creative',
#  'and',
#  'logical',
#  'Problem',
#  'solving',
#  'ability',
#  'Co-operative',
#  'and',
#  'keen',
#  'observer',
#  'Hobbies',
#  'Gardening',
#  'Playing',
#  'Volleyball',
#  'Personal',
#  'Profile',
#  'Date',
#  'of',
#  'Birth',
#  ':',
#  '12.11.1992',
#  'Gender',
#  ':',
#  'Male',
#  'Marital',
#  'status',
#  ':',
#  'Single',
#  'Languages',
#  'Known',
#  ':',
#  'Tamil',
#  ',',
#  'English',
#  'and',
#  'Hindi',
#  '(',
#  'Read',
#  'and',
#  'Write',
#  ')',
#  'Permanent',
#  'Address',
#  ':',
#  '10/1',
#  'N',
#  'S',
#  'Road',
#  ',',
#  'Marina',
#  'Lane',
#  ',',
#  'Chennai-600010',
#  'I',
#  'hereby',
#  'declare',
#  'that',
#  'all',
#  'the',
#  'details',
#  'furnished',
#  'here',
#  'are',
#  'true',
#  'to',
#  'the',
#  'best',
#  'of',
#  'my',
#  'knowledge',
#  '.',
#  'DATE',
#  ':',
#  'NAME',
#  ':',
#  'ANIL',
#  'JAIN',
#  'PLACE',
#  ':',
#  'SIGNATURE',
#  ':']

# %%
lines
# Out:
# [[('Mobile', 'NN'), (':', ':'), ('09876543210', 'CD')],
#  [('Phone', 'NN'), (':', ':'), ('044-12345678', 'NN')],
#  [('Email', 'NN'),
#   (':', ':'),
#   ('aniljain', 'NN'),
#   ('@', 'NN'),
#   ('gmail.com', 'NN')],
#  [],
#  [('ANIL', 'NNP'), ('JAIN', 'NNP')],
#  [],
#  [('Career', 'NNP'), ('objective', 'NN')],
#  [],
#  [('To', 'TO'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('growth', 'NN'),
#   ('oriented', 'VBN'),
#   ('and', 'CC'),
#   ('challenging', 'VBG'),
#   ('career', 'NN'),
#   (',', ','),
#   ('where', 'WRB'),
#   ('I', 'PRP'),
#   ('can', 'MD'),
#   ('contribute', 'VB'),
#   ('my', 'PRP$'),
#   ('knowledge', 'NN'),
#   ('and', 'CC')],
#  [('skills', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('organization', 'NN'),
#   ('and', 'CC'),
#   ('enhance', 'VB'),
#   ('my', 'PRP$'),
#   ('experience', 'NN'),
#   ('through', 'IN'),
#   ('continuous', 'JJ'),
#   ('learning', 'NN'),
#   ('and', 'CC'),
#   ('teamwork', 'NN'),
#   ('.', '.')],
#  [],
#  [],
#  [('Academic', 'NNP'), ('Qualification', 'NN')],
#  [],
#  [('Course', 'NN')],
#  [],
#  [('University/Board', 'NN')],
#  [],
#  [('Institute', 'NNP')],
#  [],
#  [('Year', 'NN'), ('of', 'IN')],
#  [('passing', 'NN')],
#  [],
#  [('Percentage/CGPA', 'NN')],
#  [],
#  [('B.E-', 'NN')],
#  [],
#  [('Mechanical', 'JJ')],
#  [('Engineering', 'VBG')],
#  [],
#  [('AnnaUniversity', 'NN')],
#  [],
#  [('Higher', 'JJR')],
#  [],
#  [('Secondary', 'JJ')],
#  [],
#  [('Matric', 'NN')],
#  [],
#  [('SSLC', 'NN')],
#  [],
#  [('Matric', 'NN')],
#  [],
#  [],
#  [],
#  [('Work', 'NN'), ('Experience', 'NN')],
#  [],
#  [],
#  [('Sri', 'NNP'), ('Muthukumaran', 'NNP')],
#  [('Institute', 'NNP'), ('of', 'IN'), ('Higher', 'NNP')],
#  [],
#  [('Technology', 'NN')],
#  [],
#  [('Nav', 'NNP'), ('Bharath', 'NNP')],
#  [('Vidyalaya', 'NN')],
#  [],
#  [('Mat.Hr.Sec.School', 'NNP'), (',', ',')],
#  [],
#  [('Mangadu', 'NN')],
#  [],
#  [('Nav', 'NNP'), ('Bharath', 'NNP')],
#  [('Vidyalaya', 'NN')],
#  [],
#  [('Mat.Hr.Sec.School', 'NNP'), (',', ',')],
#  [],
#  [('Mangadu', 'NN')],
#  [],
#  [('2012', 'CD')],
#  [],
#  [('7.44', 'CD'), ('(', '('), ('cgpa', 'NN'), (')', ')')],
#  [],
#  [('2008', 'CD')],
#  [],
#  [('76.58', 'CD')],
#  [],
#  [('2006', 'CD')],
#  [],
#  [('79.9', 'CD')],
#  [],
#  [('July2012', 'NNP'),
#   ('Dec2012', 'NNP'),
#   ('(', '('),
#   ('6months', 'CD'),
#   (')', ')'),
#   ('Works', 'VBZ'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('junior', 'JJ'),
#   ('production', 'NN'),
#   ('engineer', 'NN'),
#   ('inYONGSAN', 'NN')],
#  [],
#  [('AUTOMOTIVE', 'NNP'),
#   ('INDIA', 'NNP'),
#   ('PVT', 'NNP'),
#   ('LTD', 'NNP'),
#   (',', ','),
#   ('Papparampakkam', 'NNP')],
#  [],
#  [('Software', 'NNP'), ('proficiency', 'NN')],
#  [],
#  [],
#  [('Software', 'NNP'),
#   ('known', 'VBN'),
#   (':', ':'),
#   ('Auto', 'NNP'),
#   ('Cad', 'NNP'),
#   (',', ','),
#   ('SolidWorks', 'NNP'),
#   (',', ','),
#   ('Ansys', 'NNP'),
#   (',', ','),
#   ('Automation', 'NNP'),
#   ('Studio', 'NNP'),
#   ('.', '.')],
#  [('Office', 'NNP'),
#   ('suite', 'NN'),
#   (':', ':'),
#   ('MS-office', 'NN'),
#   ('.', '.')],
#  [],
#  [],
#  [('Area', 'NN'), ('of', 'IN'), ('Interest', 'NNP')],
#  [],
#  [],
#  [('Manufacturing', 'VBG'), ('Technology', 'NN')],
#  [('Automobile', 'NNP'), ('Engineering', 'NNP')],
#  [],
#  [],
#  [],
#  [('Mini', 'NNP'), ('Project', 'NNP')],
#  [],
#  [],
#  [],
#  [('Project', 'NNP'),
#   ('Area', 'NNP'),
#   (':', ':'),
#   ('Manufacturing', 'NNP'),
#   ('Technology', 'NNP')],
#  [('Project', 'NN'),
#   ('Title', 'NNP'),
#   (':', ':'),
#   ('Design', 'NN'),
#   ('and', 'CC'),
#   ('fabrication', 'NN'),
#   ('of', 'IN'),
#   ('Reciprocating', 'VBG'),
#   ('Saw', 'NNP')],
#  [('Project', 'JJ'),
#   ('Role', 'NNP'),
#   (':', ':'),
#   ('Team', 'NN'),
#   ('leader', 'NN')],
#  [('Software', 'NNP'),
#   ('used', 'VBD'),
#   ('for', 'IN'),
#   ('Designing', 'VBG'),
#   (':', ':'),
#   ('SolidWorks', 'NN'),
#   ('2005', 'CD')],
#  [],
#  [],
#  [('Main', 'NN'), ('Project', 'NN')],
#  [],
#  [('Project', 'NNP'),
#   ('Area', 'NNP'),
#   (':', ':'),
#   ('Design', 'NN'),
#   ('of', 'IN'),
#   ('Transmission', 'NNP'),
#   ('system', 'NN'),
#   ('.', '.')],
#  [('Project', 'NN'),
#   ('Title', 'NNP'),
#   (':', ':'),
#   ('Design', 'NN'),
#   (',', ','),
#   ('Analysis', 'NNP'),
#   ('and', 'CC'),
#   ('fabrication', 'NN'),
#   ('of', 'IN'),
#   ('Modular', 'NNP')],
#  [],
#  [('Stair', 'NN')],
#  [('Case', 'NNP'), ('Climber', 'NNP')],
#  [],
#  [('Project', 'JJ'),
#   ('Role', 'NNP'),
#   (':', ':'),
#   ('Done', 'CD'),
#   ('the', 'DT'),
#   ('Analysis', 'NN'),
#   ('and', 'CC'),
#   ('helped', 'VBD'),
#   ('in', 'IN'),
#   ('fabrication', 'NN'),
#   ('.', '.')],
#  [('Software', 'NNP'),
#   ('used', 'VBD'),
#   ('for', 'IN'),
#   ('Designing', 'VBG'),
#   (':', ':'),
#   ('Solid', 'JJ'),
#   ('Works-2010', 'NNP'),
#   ('.', '.')],
#  [('Software', 'NNP'),
#   ('used', 'VBD'),
#   ('for', 'IN'),
#   ('Analyzing', 'VBG'),
#   (':', ':'),
#   ('Ansys', '$'),
#   ('11', 'CD')],
#  [],
#  [],
#  [('Industrial', 'NNP'), ('visits', 'NNS')],
#  [],
#  [],
#  [('Integral', 'JJ'),
#   ('Coach', 'NNP'),
#   ('Factory', 'NNP'),
#   ('(', '('),
#   ('ICF', 'NNP'),
#   (')', ')'),
#   (',', ','),
#   ('Chennai', 'NNP')],
#  [('Karnataka', 'NNP'),
#   ('Turned', 'VBD'),
#   ('Components', 'NNP'),
#   (',', ','),
#   ('Hosur', 'NNP')],
#  [],
#  [],
#  [('Training', 'NN'),
#   ('and', 'CC'),
#   ('Workshops', 'NNP'),
#   ('undergone', 'NN')],
#  [],
#  [('Implant', 'JJ'), ('training', 'NN'), (':', ':')],
#  [],
#  [('Organization', 'NN'),
#   (':', ':'),
#   ('Integral', 'JJ'),
#   ('Coach', 'NNP'),
#   ('Factory', 'NNP'),
#   ('(', '('),
#   ('ICF', 'NNP'),
#   (')', ')'),
#   (',', ','),
#   ('Perumbur', 'NNP'),
#   (',', ','),
#   ('Chennai-600', 'NNP'),
#   ('038', 'CD'),
#   ('.', '.')],
#  [('Duration', 'NN'), (':', ':'), ('7', 'CD'), ('days', 'NNS')],
#  [('Knowledge', 'NN'),
#   ('Gained', 'VBN'),
#   (':', ':'),
#   ('Learnt', 'VB'),
#   ('about', 'IN'),
#   ('various', 'JJ'),
#   ('machining', 'NN'),
#   ('processes', 'NNS')],
#  [],
#  [],
#  [('Work', 'NN'), ('shop', 'NN'), (':', ':')],
#  [],
#  [],
#  [('Robotics', 'NNS'), (':', ':')],
#  [],
#  [('Place', 'NN'), (':', ':'), ('college', 'NN'), ('campus', 'NN')],
#  [('Period', 'NNP'),
#   ('and', 'CC'),
#   ('Time', 'NNP'),
#   (':', ':'),
#   ('21-24th', 'JJ'),
#   ('Jan', 'NNP'),
#   ('2011', 'CD'),
#   ('.', '.')],
#  [],
#  [('Papers', 'NNS'), ('presented', 'VBD')],
#  [],
#  [],
#  [('Presented', 'VBN'),
#   ('a', 'DT'),
#   ('Paper', 'NNP'),
#   ('on', 'IN'),
#   ('Power', 'NNP'),
#   ('Production', 'NNP'),
#   ('Through', 'IN'),
#   ('Bladeless', 'NNP'),
#   ('Turbine', 'NNP'),
#   ('.', '.'),
#   ('at', 'IN'),
#   ('Misrimal', 'NNP'),
#   ('Navajee', 'NNP')],
#  [],
#  [('Munoth', 'NNP'),
#   ('Jain', 'NNP'),
#   ('Engineering', 'NNP'),
#   ('College', 'NNP')],
#  [],
#  [],
#  [('Achievements', 'NNS'),
#   ('and', 'CC'),
#   ('Extra-curricular', 'JJ'),
#   ('activities', 'NNS')],
#  [],
#  [],
#  [('Participated', 'VBN'),
#   ('and', 'CC'),
#   ('won', 'VBD'),
#   ('prizes', 'NNS'),
#   ('in', 'IN'),
#   ('English', 'NNP'),
#   ('essay', 'VBP'),
#   ('competition', 'NN'),
#   ('at', 'IN'),
#   ('school', 'NN'),
#   ('level', 'NN'),
#   ('.', '.')],
#  [('Participated', 'VBN'),
#   ('and', 'CC'),
#   ('won', 'VBD'),
#   ('prizes', 'NNS'),
#   ('in', 'IN'),
#   ('drawing', 'VBG'),
#   ('competition', 'NN'),
#   ('conducted', 'VBN'),
#   ('by', 'IN'),
#   ('Road', 'NNP'),
#   ('safety', 'NN'),
#   ('Educational', 'NNP'),
#   ('&', 'CC')],
#  [],
#  [('Research', 'NNP'),
#   ('Service', 'NNP'),
#   ('Society', 'NNP'),
#   ('-', ':'),
#   ('at', 'IN'),
#   ('school', 'NN'),
#   ('level', 'NN'),
#   ('.', '.')],
#  [],
#  [('Active', 'JJ'),
#   ('participant', 'NN'),
#   ('of', 'IN'),
#   ('NSS', 'NNP'),
#   ('and', 'CC'),
#   ('Active', 'NNP'),
#   ('blood', 'NN'),
#   ('donor', 'NN'),
#   ('.', '.')],
#  [],
#  [],
#  [],
#  [('Personal', 'JJ'), ('Trait', 'NN')],
#  [],
#  [],
#  [('Creative', 'JJ'), ('and', 'CC'), ('logical', 'JJ')],
#  [('Problem', 'NNP'), ('solving', 'VBG'), ('ability', 'NN')],
#  [('Co-operative', 'JJ'), ('and', 'CC'), ('keen', 'JJ'), ('observer', 'NN')],
#  [],
#  [],
#  [('Hobbies', 'NNS')],
#  [],
#  [('Gardening', 'VBG')],
#  [('Playing', 'VBG'), ('Volleyball', 'NN')],
#  [],
#  [],
#  [('Personal', 'JJ'), ('Profile', 'NN')],
#  [('Date', 'NNP'),
#   ('of', 'IN'),
#   ('Birth', 'NNP'),
#   (':', ':'),
#   ('12.11.1992', 'CD')],
#  [('Gender', 'NN'), (':', ':'), ('Male', 'NN')],
#  [('Marital', 'JJ'), ('status', 'NN'), (':', ':'), ('Single', 'NN')],
#  [('Languages', 'NNS'),
#   ('Known', 'VBN'),
#   (':', ':'),
#   ('Tamil', 'NNP'),
#   (',', ','),
#   ('English', 'NNP'),
#   ('and', 'CC'),
#   ('Hindi', 'NNP'),
#   ('(', '('),
#   ('Read', 'NNP'),
#   ('and', 'CC'),
#   ('Write', 'NNP'),
#   (')', ')')],
#  [('Permanent', 'JJ'),
#   ('Address', 'NN'),
#   (':', ':'),
#   ('10/1', 'CD'),
#   ('N', 'NNP'),
#   ('S', 'NNP'),
#   ('Road', 'NNP'),
#   (',', ','),
#   ('Marina', 'NNP'),
#   ('Lane', 'NNP'),
#   (',', ','),
#   ('Chennai-600010', 'NNP')],
#  [],
#  [],
#  [('I', 'PRP'),
#   ('hereby', 'VBP'),
#   ('declare', 'VB'),
#   ('that', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('details', 'NNS'),
#   ('furnished', 'VBN'),
#   ('here', 'RB'),
#   ('are', 'VBP'),
#   ('true', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('knowledge', 'NN'),
#   ('.', '.')],
#  [],
#  [('DATE', 'NN'),
#   (':', ':'),
#   ('NAME', 'NN'),
#   (':', ':'),
#   ('ANIL', 'NNP'),
#   ('JAIN', 'NNP')],
#  [],
#  [('PLACE', 'NN'), (':', ':'), ('SIGNATURE', 'NN'), (':', ':')],
#  [],
#  [],
#  []]

# %%
sentences
# Out:
# [[('Mobile', 'NN'),
#   (':', ':'),
#   ('09876543210', 'CD'),
#   ('Phone', 'NN'),
#   (':', ':'),
#   ('044-12345678', 'JJ'),
#   ('Email', 'NN'),
#   (':', ':'),
#   ('aniljain', 'NN'),
#   ('@', 'NNP'),
#   ('gmail.com', 'NN'),
#   ('ANIL', 'NNP'),
#   ('JAIN', 'NNP'),
#   ('Career', 'NNP'),
#   ('objective', 'NN'),
#   ('To', 'TO'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('growth', 'NN'),
#   ('oriented', 'VBN'),
#   ('and', 'CC'),
#   ('challenging', 'VBG'),
#   ('career', 'NN'),
#   (',', ','),
#   ('where', 'WRB'),
#   ('I', 'PRP'),
#   ('can', 'MD'),
#   ('contribute', 'VB'),
#   ('my', 'PRP$'),
#   ('knowledge', 'NN'),
#   ('and', 'CC'),
#   ('skills', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('organization', 'NN'),
#   ('and', 'CC'),
#   ('enhance', 'VB'),
#   ('my', 'PRP$'),
#   ('experience', 'NN'),
#   ('through', 'IN'),
#   ('continuous', 'JJ'),
#   ('learning', 'NN'),
#   ('and', 'CC'),
#   ('teamwork', 'NN'),
#   ('.', '.')],
#  [('Academic', 'JJ'),
#   ('Qualification', 'NNP'),
#   ('Course', 'NNP'),
#   ('University/Board', 'NNP'),
#   ('Institute', 'NNP'),
#   ('Year', 'NNP'),
#   ('of', 'IN'),
#   ('passing', 'VBG'),
#   ('Percentage/CGPA', 'NNP'),
#   ('B.E-', 'NNP'),
#   ('Mechanical', 'NNP'),
#   ('Engineering', 'NNP'),
#   ('AnnaUniversity', 'NNP'),
#   ('Higher', 'NNP'),
#   ('Secondary', 'NNP'),
#   ('Matric', 'NNP'),
#   ('SSLC', 'NNP'),
#   ('Matric', 'NNP'),
#   ('Work', 'NNP'),
#   ('Experience', 'NNP'),
#   ('Sri', 'NNP'),
#   ('Muthukumaran', 'NNP'),
#   ('Institute', 'NNP'),
#   ('of', 'IN'),
#   ('Higher', 'NNP'),
#   ('Technology', 'NNP'),
#   ('Nav', 'NNP'),
#   ('Bharath', 'NNP'),
#   ('Vidyalaya', 'NNP'),
#   ('Mat.Hr.Sec.School', 'NNP'),
#   (',', ','),
#   ('Mangadu', 'NNP'),
#   ('Nav', 'NNP'),
#   ('Bharath', 'NNP'),
#   ('Vidyalaya', 'NNP'),
#   ('Mat.Hr.Sec.School', 'NNP'),
#   (',', ','),
#   ('Mangadu', 'NNP'),
#   ('2012', 'CD'),
#   ('7.44', 'NNP'),
#   ('(', '('),
#   ('cgpa', 'NN'),
#   (')', ')'),
#   ('2008', 'CD'),
#   ('76.58', 'CD'),
#   ('2006', 'CD'),
#   ('79.9', 'CD'),
#   ('July2012', 'NNP'),
#   ('Dec2012', 'NNP'),
#   ('(', '('),
#   ('6months', 'CD'),
#   (')', ')'),
#   ('Works', 'VBZ'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('junior', 'JJ'),
#   ('production', 'NN'),
#   ('engineer', 'NN'),
#   ('inYONGSAN', 'NN'),
#   ('AUTOMOTIVE', 'NNP'),
#   ('INDIA', 'NNP'),
#   ('PVT', 'NNP'),
#   ('LTD', 'NNP'),
#   (',', ','),
#   ('Papparampakkam', 'NNP'),
#   ('Software', 'NNP'),
#   ('proficiency', 'NN'),
#   ('Software', 'NNP'),
#   ('known', 'VBN'),
#   (':', ':'),
#   ('Auto', 'NNP'),
#   ('Cad', 'NNP'),
#   (',', ','),
#   ('SolidWorks', 'NNP'),
#   (',', ','),
#   ('Ansys', 'NNP'),
#   (',', ','),
#   ('Automation', 'NNP'),
#   ('Studio', 'NNP'),
#   ('.', '.')],
#  [('Office', 'NNP'),
#   ('suite', 'NN'),
#   (':', ':'),
#   ('MS-office', 'NN'),
#   ('.', '.')],
#  [('Area', 'NN'),
#   ('of', 'IN'),
#   ('Interest', 'NNP'),
#   ('Manufacturing', 'NNP'),
#   ('Technology', 'NNP'),
#   ('Automobile', 'NNP'),
#   ('Engineering', 'NNP'),
#   ('Mini', 'NNP'),
#   ('Project', 'NNP'),
#   ('Project', 'NNP'),
#   ('Area', 'NNP'),
#   (':', ':'),
#   ('Manufacturing', 'NNP'),
#   ('Technology', 'NNP'),
#   ('Project', 'NNP'),
#   ('Title', 'NNP'),
#   (':', ':'),
#   ('Design', 'NN'),
#   ('and', 'CC'),
#   ('fabrication', 'NN'),
#   ('of', 'IN'),
#   ('Reciprocating', 'VBG'),
#   ('Saw', 'NNP'),
#   ('Project', 'NNP'),
#   ('Role', 'NNP'),
#   (':', ':'),
#   ('Team', 'NN'),
#   ('leader', 'NN'),
#   ('Software', 'NNP'),
#   ('used', 'VBD'),
#   ('for', 'IN'),
#   ('Designing', 'VBG'),
#   (':', ':'),
#   ('SolidWorks', 'JJ'),
#   ('2005', 'CD'),
#   ('Main', 'NNP'),
#   ('Project', 'NNP'),
#   ('Project', 'NNP'),
#   ('Area', 'NNP'),
#   (':', ':'),
#   ('Design', 'NN'),
#   ('of', 'IN'),
#   ('Transmission', 'NNP'),
#   ('system', 'NN'),
#   ('.', '.')],
#  [('Project', 'NN'),
#   ('Title', 'NNP'),
#   (':', ':'),
#   ('Design', 'NN'),
#   (',', ','),
#   ('Analysis', 'NNP'),
#   ('and', 'CC'),
#   ('fabrication', 'NN'),
#   ('of', 'IN'),
#   ('Modular', 'NNP'),
#   ('Stair', 'NNP'),
#   ('Case', 'NNP'),
#   ('Climber', 'NNP'),
#   ('Project', 'NNP'),
#   ('Role', 'NNP'),
#   (':', ':'),
#   ('Done', 'CD'),
#   ('the', 'DT'),
#   ('Analysis', 'NN'),
#   ('and', 'CC'),
#   ('helped', 'VBD'),
#   ('in', 'IN'),
#   ('fabrication', 'NN'),
#   ('.', '.')],
#  [('Software', 'NNP'),
#   ('used', 'VBD'),
#   ('for', 'IN'),
#   ('Designing', 'VBG'),
#   (':', ':'),
#   ('Solid', 'JJ'),
#   ('Works-2010', 'NNP'),
#   ('.', '.')],
#  [('Software', 'NNP'),
#   ('used', 'VBD'),
#   ('for', 'IN'),
#   ('Analyzing', 'VBG'),
#   (':', ':'),
#   ('Ansys', '$'),
#   ('11', 'CD'),
#   ('Industrial', 'NNP'),
#   ('visits', 'NNS'),
#   ('Integral', 'NNP'),
#   ('Coach', 'NNP'),
#   ('Factory', 'NNP'),
#   ('(', '('),
#   ('ICF', 'NNP'),
#   (')', ')'),
#   (',', ','),
#   ('Chennai', 'NNP'),
#   ('Karnataka', 'NNP'),
#   ('Turned', 'VBD'),
#   ('Components', 'NNP'),
#   (',', ','),
#   ('Hosur', 'NNP'),
#   ('Training', 'NNP'),
#   ('and', 'CC'),
#   ('Workshops', 'NNP'),
#   ('undergone', 'NN'),
#   ('Implant', 'NNP'),
#   ('training', 'NN'),
#   (':', ':'),
#   ('Organization', 'NN'),
#   (':', ':'),
#   ('Integral', 'JJ'),
#   ('Coach', 'NNP'),
#   ('Factory', 'NNP'),
#   ('(', '('),
#   ('ICF', 'NNP'),
#   (')', ')'),
#   (',', ','),
#   ('Perumbur', 'NNP'),
#   (',', ','),
#   ('Chennai-600', 'NNP'),
#   ('038', 'CD'),
#   ('.', '.')],
#  [('Duration', 'NN'),
#   (':', ':'),
#   ('7', 'CD'),
#   ('days', 'NNS'),
#   ('Knowledge', 'NNP'),
#   ('Gained', 'VBD'),
#   (':', ':'),
#   ('Learnt', 'VB'),
#   ('about', 'IN'),
#   ('various', 'JJ'),
#   ('machining', 'VBG'),
#   ('processes', 'NNS'),
#   ('Work', 'NNP'),
#   ('shop', 'NN'),
#   (':', ':'),
#   ('Robotics', 'NNS'),
#   (':', ':'),
#   ('Place', 'NN'),
#   (':', ':'),
#   ('college', 'NN'),
#   ('campus', 'NN'),
#   ('Period', 'NNP'),
#   ('and', 'CC'),
#   ('Time', 'NNP'),
#   (':', ':'),
#   ('21-24th', 'JJ'),
#   ('Jan', 'NNP'),
#   ('2011', 'CD'),
#   ('.', '.')],
#  [('Papers', 'NNS'),
#   ('presented', 'VBD'),
#   ('Presented', 'VBD'),
#   ('a', 'DT'),
#   ('Paper', 'NNP'),
#   ('on', 'IN'),
#   ('Power', 'NNP'),
#   ('Production', 'NNP'),
#   ('Through', 'IN'),
#   ('Bladeless', 'NNP'),
#   ('Turbine', 'NNP'),
#   ('.', '.')],
#  [('at', 'IN'),
#   ('Misrimal', 'NNP'),
#   ('Navajee', 'NNP'),
#   ('Munoth', 'NNP'),
#   ('Jain', 'NNP'),
#   ('Engineering', 'NNP'),
#   ('College', 'NNP'),
#   ('Achievements', 'NNP'),
#   ('and', 'CC'),
#   ('Extra-curricular', 'JJ'),
#   ('activities', 'NNS'),
#   ('Participated', 'VBD'),
#   ('and', 'CC'),
#   ('won', 'VBD'),
#   ('prizes', 'NNS'),
#   ('in', 'IN'),
#   ('English', 'NNP'),
#   ('essay', 'VBP'),
#   ('competition', 'NN'),
#   ('at', 'IN'),
#   ('school', 'NN'),
#   ('level', 'NN'),
#   ('.', '.')],
#  [('Participated', 'VBN'),
#   ('and', 'CC'),
#   ('won', 'VBD'),
#   ('prizes', 'NNS'),
#   ('in', 'IN'),
#   ('drawing', 'VBG'),
#   ('competition', 'NN'),
#   ('conducted', 'VBN'),
#   ('by', 'IN'),
#   ('Road', 'NNP'),
#   ('safety', 'NN'),
#   ('Educational', 'NNP'),
#   ('&', 'CC'),
#   ('Research', 'NNP'),
#   ('Service', 'NNP'),
#   ('Society', 'NNP'),
#   ('-', ':'),
#   ('at', 'IN'),
#   ('school', 'NN'),
#   ('level', 'NN'),
#   ('.', '.')],
#  [('Active', 'JJ'),
#   ('participant', 'NN'),
#   ('of', 'IN'),
#   ('NSS', 'NNP'),
#   ('and', 'CC'),
#   ('Active', 'NNP'),
#   ('blood', 'NN'),
#   ('donor', 'NN'),
#   ('.', '.')],
#  [('Personal', 'JJ'),
#   ('Trait', 'NNP'),
#   ('Creative', 'NNP'),
#   ('and', 'CC'),
#   ('logical', 'JJ'),
#   ('Problem', 'NNP'),
#   ('solving', 'VBG'),
#   ('ability', 'NN'),
#   ('Co-operative', 'NNP'),
#   ('and', 'CC'),
#   ('keen', 'VB'),
#   ('observer', 'JJ'),
#   ('Hobbies', 'NNPS'),
#   ('Gardening', 'VBG'),
#   ('Playing', 'VBG'),
#   ('Volleyball', 'NNP'),
#   ('Personal', 'NNP'),
#   ('Profile', 'NNP'),
#   ('Date', 'NNP'),
#   ('of', 'IN'),
#   ('Birth', 'NNP'),
#   (':', ':'),
#   ('12.11.1992', 'CD'),
#   ('Gender', 'NN'),
#   (':', ':'),
#   ('Male', 'NNP'),
#   ('Marital', 'NNP'),
#   ('status', 'NN'),
#   (':', ':'),
#   ('Single', 'NNP'),
#   ('Languages', 'NNP'),
#   ('Known', 'NNP'),
#   (':', ':'),
#   ('Tamil', 'NNP'),
#   (',', ','),
#   ('English', 'NNP'),
#   ('and', 'CC'),
#   ('Hindi', 'NNP'),
#   ('(', '('),
#   ('Read', 'NNP'),
#   ('and', 'CC'),
#   ('Write', 'NNP'),
#   (')', ')'),
#   ('Permanent', 'NNP'),
#   ('Address', 'NNP'),
#   (':', ':'),
#   ('10/1', 'CD'),
#   ('N', 'NNP'),
#   ('S', 'NNP'),
#   ('Road', 'NNP'),
#   (',', ','),
#   ('Marina', 'NNP'),
#   ('Lane', 'NNP'),
#   (',', ','),
#   ('Chennai-600010', 'NNP'),
#   ('I', 'PRP'),
#   ('hereby', 'VBP'),
#   ('declare', 'VB'),
#   ('that', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('details', 'NNS'),
#   ('furnished', 'VBN'),
#   ('here', 'RB'),
#   ('are', 'VBP'),
#   ('true', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('best', 'JJS'),
#   ('of', 'IN'),
#   ('my', 'PRP$'),
#   ('knowledge', 'NN'),
#   ('.', '.')],
#  [('DATE', 'NN'),
#   (':', ':'),
#   ('NAME', 'NN'),
#   (':', ':'),
#   ('ANIL', 'NNP'),
#   ('JAIN', 'NNP'),
#   ('PLACE', 'NNP'),
#   (':', ':'),
#   ('SIGNATURE', 'NN'),
#   (':', ':')]]

# %%
# getemail
def getEmail(inputString): 
        '''
        Given an input string, returns possible matches for emails. Uses regular expression based matching.
        Needs an input string, a dictionary where values are being stored, and an optional parameter for debugging.
        Modules required: clock from time, code.
        '''

        email = None
        try:
            pattern = re.compile(r'\S*@\S*')
            matches = pattern.findall(inputString) # Gets all email addresses as a list
            email = matches
        except Exception as e:
            print(e)

        return email


# convert bytes datatype to string
str = data.decode('ISO-8859-1')

email = getEmail(str)
email
# Out:
# ['aniljain@gmail.com']

# %%
def getPhone(inputString):
        '''
        Given an input string, returns possible matches for phone numbers. Uses regular expression based matching.
        Needs an input string, a dictionary where values are being stored, and an optional parameter for debugging.
        Modules required: clock from time, code.
        '''

        number = None
        try:
            pattern = re.compile(r'([+(]?\d+[)\-]?[ \t\r\f\v]*[(]?\d{2,}[()\-]?[ \t\r\f\v]*\d{2,}[()\-]?[ \t\r\f\v]*\d*[ \t\r\f\v]*\d*[ \t\r\f\v]*)')
                # Understanding the above regex
                # +91 or (91) -> [+(]? \d+ -?
                # Metacharacters have to be escaped with \ outside of character classes; inside only hyphen has to be escaped
                # hyphen has to be escaped inside the character class if you're not incidication a range
                # General number formats are 123 456 7890 or 12345 67890 or 1234567890 or 123-456-7890, hence 3 or more digits
                # Amendment to above - some also have (0000) 00 00 00 kind of format
                # \s* is any whitespace character - careful, use [ \t\r\f\v]* instead since newlines are trouble
            match = pattern.findall(inputString)
            # match = [re.sub(r'\s', '', el) for el in match]
                # Get rid of random whitespaces - helps with getting rid of 6 digits or fewer (e.g. pin codes) strings
            # substitute the characters we don't want just for the purpose of checking
            match = [re.sub(r'[,.]', '', el) for el in match if len(re.sub(r'[()\-.,\s+]', '', el))>6]
                # Taking care of years, eg. 2001-2004 etc.
            match = [re.sub(r'\D$', '', el).strip() for el in match]
                # $ matches end of string. This takes care of random trailing non-digit characters. \D is non-digit characters
            match = [el for el in match if len(re.sub(r'\D','',el)) <= 15]
                # Remove number strings that are greater than 15 digits
            try:
                for el in list(match):
                    # Create a copy of the list since you're iterating over it
                    if len(el.split('-')) > 3: continue # Year format YYYY-MM-DD
                    for x in el.split("-"):
                        try:
                            # Error catching is necessary because of possibility of stray non-number characters
                            # if int(re.sub(r'\D', '', x.strip())) in range(1900, 2100):
                            if x.strip()[-4:].isdigit():
                                if int(x.strip()[-4:]) in range(1900, 2100):
                                    # Don't combine the two if statements to avoid a type conversion error
                                    match.remove(el)
                        except:
                            pass
            except:
                pass
            number = match
        except:
            pass

        return number
    
phone = getPhone(str)
phone
# Out:
# ['09876543210', '044-12345678']

# %%
# def getName(inputString):
#         '''
#         Given an input string, returns possible matches for names. Uses regular expression based matching.
#         Needs an input string, a dictionary where values are being stored, and an optional parameter for debugging.
#         Modules required: clock from time, code.
#         '''

#         # Reads Indian Names from the file, reduce all to lower case for easy comparision [Name lists]
#         indianNames = open("allNames.txt", "r").read().lower()
#         # Lookup in a set is much faster
#         indianNames = set(indianNames.split())
        

#         otherNameHits = []
#         nameHits = []
#         name = None

#         try:
#             # tokens, lines, sentences = self.preprocess(inputString)
# #             tokens, lines, sentences = self.tokens, self.lines, self.sentences
#             # Try a regex chunk parser
#             # grammar = r'NAME: {<NN.*><NN.*>|<NN.*><NN.*><NN.*>}'
#             grammar = r'NAME: {<NN.*><NN.*><NN.*>*}'
#             # Noun phrase chunk is made out of two or three tags of type NN. (ie NN, NNP etc.) - typical of a name. {2,3} won't work, hence the syntax
#             # Note the correction to the rule. Change has been made later.
#             chunkParser = nltk.RegexpParser(grammar)
#             all_chunked_tokens = []
#             for tagged_tokens in lines:
#                 # Creates a parse tree
#                 if len(tagged_tokens) == 0: continue # Prevent it from printing warnings
#                 chunked_tokens = chunkParser.parse(tagged_tokens)
#                 all_chunked_tokens.append(chunked_tokens)
#                 for subtree in chunked_tokens.subtrees():
#                     #  or subtree.label() == 'S' include in if condition if required
#                     if subtree.label() == 'NAME':
#                         for ind, leaf in enumerate(subtree.leaves()):
#                             if leaf[0].lower() in indianNames and 'NN' in leaf[1]:
#                                 # Case insensitive matching, as indianNames have names in lowercase
#                                 # Take only noun-tagged tokens
#                                 # Surname is not in the name list, hence if match is achieved add all noun-type tokens
#                                 # Pick upto 3 noun entities
#                                 hit = " ".join([el[0] for el in subtree.leaves()[ind:ind+3]])
#                                 # Check for the presence of commas, colons, digits - usually markers of non-named entities 
#                                 if re.compile(r'[\d,:]').search(hit): continue
#                                 nameHits.append(hit)
#                                 # Need to iterate through rest of the leaves because of possible mis-matches
#             # Going for the first name hit
#             if len(nameHits) > 0:
#                 nameHits = [re.sub(r'[^a-zA-Z \-]', '', el).strip() for el in nameHits] 
#                 name = " ".join([el[0].upper()+el[1:].lower() for el in nameHits[0].split() if len(el)>0])
#                 otherNameHits = nameHits[1:]

#         except Exception as e:
#             print(traceback.format_exc())
#             print(e)

#         return name, otherNameHits  

# [name, othreNameHits] = getName(str)
# name
# otherNameHits

# %%
def getExperience(inputString):
        experience=[]
        try:
            for sentence in lines:#find the index of the sentence where the degree is find and then analyse that sentence
                    sen=" ".join([words[0].lower() for words in sentence]) #string of words in sentence
                    if re.search('experience',sen):
                        sen_tokenised= nltk.word_tokenize(sen)
                        tagged = nltk.pos_tag(sen_tokenised)
                        entities = nltk.chunk.ne_chunk(tagged)
                        for subtree in entities.subtrees():
                            for leaf in subtree.leaves():
                                if leaf[1]=='CD':
                                    experience=leaf[0]
        except Exception as e:
            print(traceback.format_exc())
            print(e)
            
        return experience
    
experience = getExperience(str)
experience
# Out:
# []

# %%
#Define your grammar using regular expressions
grammar = ('''NP: {<NNP> <NNP>} # NP''')
chunkParser = nltk.RegexpParser(grammar)
tagged = nltk.pos_tag(nltk.word_tokenize(str))
tagged[:2]
# Out:
# [('Mobile', 'NN'), (':', ':')]

# %%
from pyresparser import ResumeParser
import os
from docx import Document
filed = "resume0.pdf"

try:
    doc = Document()
    with open(filed, 'r') as file:
        doc.add_paragraph(file.read())
    doc.save("text.docx")
    data = ResumeParser("text.docx").get_extracted_data()
    print(data['skills'])
except:
    data = ResumeParser(filed).get_extracted_data()
    print(data['skills'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11652/2986524749.py in <module>
#       7     doc = Document()
# ----> 8     with str as file:
#       9         doc.add_paragraph(file)
#
# AttributeError: __enter__
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11652/2986524749.py in <module>
#      12     print(data['skills'])
#      13 except:
# ---> 14     data = ResumeParser(str).get_extracted_data()
#      15     print(data['skills'])
#
# ~\anaconda3\lib\site-packages\pyresparser\resume_parser.py in __init__(self, resume, skills_file, custom_regex)
#      18         custom_regex=None
#      19     ):
# ---> 20         nlp = spacy.load('en_core_web_sm')
#      21         custom_nlp = spacy.load(os.path.dirname(os.path.abspath(__file__)))
#      22         self.__skills_file = skills_file
#
# ~\anaconda3\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     425     if name in OLD_MODEL_SHORTCUTS:
#     426         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 427     raise IOError(Errors.E050.format(name=name))
#     428
#     429
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
