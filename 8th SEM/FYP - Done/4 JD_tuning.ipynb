# %%
# !pip install -U gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Collecting gensim
#   Downloading gensim-4.2.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |████████████████████████████████| 24.1 MB 1.4 MB/s
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (6.0.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.6)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.2.0

# %%
import pandas as pd
import numpy as np
import gensim
from sklearn.linear_model import LogisticRegression
from gensim.models.doc2vec import TaggedDocument
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.svm import SVC
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from gensim.models import Doc2Vec
import multiprocessing
from sklearn import utils
from sklearn.model_selection import train_test_split
from gensim.parsing.preprocessing import remove_stopwords
from gensim.utils import simple_preprocess
from gensim.parsing.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
import nltk

import itertools
from gensim.similarities import MatrixSimilarity
from gensim.parsing.preprocessing import preprocess_documents
from gensim.parsing.preprocessing import preprocess_string

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
data = pd.read_csv("jd.csv")
data
# Out:
#       id        category                                                 jd
# 0      1  cloud engineer  Company is seeking a Data Architect. The indiv...
# 1      2  cloud engineer  Cloud Architect  Lowell, MA 6+ months   Resear...
# 2      3  cloud engineer  Cloud Architect - AWSJob Type: Contract, Contr...
# 3      4  cloud engineer  Senior Software Architect (Perm)Charlestown, M...
# 4      5  cloud engineer  Our client, a well known and highly profitable...
# ..   ...             ...                                                ...
# 501  502  java developer  Synechron is a recognized leader and expert in...
# 502  503  java developer  Note: For further information please contact S...
# 503  504  java developer  Synechron on behalf of our client, a global le...
# 504  505  java developer  Please contactPatrick TrainorCanyon Associates...
# 505  506  java developer  Java Developer – Algorithmic Trading - NYCDura...
#
# [506 rows x 3 columns]

# %%
def clean(text):
    text = re.sub('http\S+\s*', ' ', text)  # remove URLs
    text = re.sub('RT|cc', ' ', text)  # remove RT and cc
    text = re.sub('#\S+', '', text)  # remove hashtags
    text = re.sub('@\S+', '  ', text)  # remove mentions
    text = re.sub('[%s]' % re.escape("""!"$%&'()*,-/:;<=>?@[\]^_`{|}~"""), ' ', text)  # remove punctuations
    text = re.sub(r'[^\x00-\x7f]',r' ', text) 
    text = re.sub('\s+', ' ', text)  # remove extra whitespace
    return text

# %%
data['cleaned_jd'] = ""

#cleaning data
data['cleaned_jd'] = data.jd.apply(lambda x: clean(x))

# Removing the stop words
data['cleaned_jd'] = data.cleaned_jd.apply(lambda x: remove_stopwords(x))

# Tokenize the text column
data['cleaned_jd'] = [simple_preprocess(line, deacc=True) for line in data['cleaned_jd']] 

# Get the stemmed_tokens
porter_stemmer = PorterStemmer()
data['cleaned_jd'] = [[porter_stemmer.stem(word) for word in tokens] for tokens in data['cleaned_jd'] ]

# get the lammatized tokens
lemmatizer = WordNetLemmatizer() 
data['cleaned_jd'] = [[lemmatizer.lemmatize(word) for word in tokens] for tokens in data['cleaned_jd'] ]

# %%
data
# Out:
#       id        category                                                 jd  \
# 0      1  cloud engineer  Company is seeking a Data Architect. The indiv...
# 1      2  cloud engineer  Cloud Architect  Lowell, MA 6+ months   Resear...
# 2      3  cloud engineer  Cloud Architect - AWSJob Type: Contract, Contr...
# 3      4  cloud engineer  Senior Software Architect (Perm)Charlestown, M...
# 4      5  cloud engineer  Our client, a well known and highly profitable...
# ..   ...             ...                                                ...
# 501  502  java developer  Synechron is a recognized leader and expert in...
# 502  503  java developer  Note: For further information please contact S...
# 503  504  java developer  Synechron on behalf of our client, a global le...
# 504  505  java developer  Please contactPatrick TrainorCanyon Associates...
# 505  506  java developer  Java Developer – Algorithmic Trading - NYCDura...
#
#                                             cleaned_jd
# 0    [compani, seek, data, architect, the, individu...
# 1    [cloud, architect, lowel, ma, month, research,...
# 2    [cloud, architect, awsjob, type, contract, con...
# 3    [senior, softwar, architect, perm, charlestown...
# 4    [our, client, known, highli, profit, softwar, ...
# ..                                                 ...
# 501  [synechron, recogn, leader, expert, build, bus...
# 502  [note, for, inform, contact, sonal, hatila, so...
# 503  [synechron, behalf, client, global, leader, di...
# 504  [plea, contactpatrick, trainorcanyon, associ, ...
# 505  [java, develop, algorithm, trade, nycdur, cont...
#
# [506 rows x 4 columns]

# %%
dm = [0, 1]
vector_size = [200, 300, 400, 500, 600, 700]
window = [3, 5, 10]
epochs = [10, 20, 30]
paramsList = [{'dm': item[0],
               'vector_size': item[1],
               'window': item[2],
               'epochs' : item[3],
               } for item in
                 list(itertools.product(*[dm,
                                          vector_size,
                                          window,
                                          epochs]))
              ]

# %%
def evaluation_doc2vec(params, processed_corpus, top=10):
  tagged_corpus = [TaggedDocument(d, [i]) for i, d in enumerate(processed_corpus)]
  scoreList = []
  for param in params: 
    param['score'] = 0
    model = None
    try:
      model = Doc2Vec(tagged_corpus,
                      dm=param['dm'], 
                      vector_size=param['vector_size'], 
                      window=param['window'], 
                      min_count=1, 
                      epochs=param['epochs'], 
                      hs=1)
      for i in range(len(data)):
        new_doc = data['cleaned_jd'][i]
        test_doc_vector = model.infer_vector(new_doc)
        sims=model.docvecs.most_similar(positive=[test_doc_vector])
        topSims = sims[:10]
        for ii in range(len(topSims)):
          if (data['category'][i]) == (data['category'][topSims[ii][0]]):
            param['score'] = param['score'] + (top - ii)
      print(param)
      scoreList.append(param)
    except Exception as error:
      print(f'Cannot evaluate model with parameters {param} because of error: {error}')
      continue
  return scoreList

# %%
scoreList = evaluation_doc2vec(paramsList ,data['cleaned_jd'].values)
scoreList = pd.DataFrame(scoreList)
scoreList = scoreList.sort_values(by = ['score'], ascending = False)
print(scoreList)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
# {'dm': 0, 'vector_size': 200, 'window': 3, 'epochs': 10, 'score': 18617}
# {'dm': 0, 'vector_size': 200, 'window': 3, 'epochs': 20, 'score': 17522}
# {'dm': 0, 'vector_size': 200, 'window': 3, 'epochs': 30, 'score': 16796}
# {'dm': 0, 'vector_size': 200, 'window': 5, 'epochs': 10, 'score': 18575}
# {'dm': 0, 'vector_size': 200, 'window': 5, 'epochs': 20, 'score': 17574}
# {'dm': 0, 'vector_size': 200, 'window': 5, 'epochs': 30, 'score': 16836}
# {'dm': 0, 'vector_size': 200, 'window': 10, 'epochs': 10, 'score': 18580}
# {'dm': 0, 'vector_size': 200, 'window': 10, 'epochs': 20, 'score': 17522}
# {'dm': 0, 'vector_size': 200, 'window': 10, 'epochs': 30, 'score': 16718}
# {'dm': 0, 'vector_size': 300, 'window': 3, 'epochs': 10, 'score': 18533}
# {'dm': 0, 'vector_size': 300, 'window': 3, 'epochs': 20, 'score': 17716}
# {'dm': 0, 'vector_size': 300, 'window': 3, 'epochs': 30, 'score': 16908}
# {'dm': 0, 'vector_size': 300, 'window': 5, 'epochs': 10, 'score': 18547}
# {'dm': 0, 'vector_size': 300, 'window': 5, 'epochs': 20, 'score': 17457}
# {'dm': 0, 'vector_size': 300, 'window': 5, 'epochs': 30, 'score': 16791}
# {'dm': 0, 'vector_size': 300, 'window': 10, 'epochs': 10, 'score': 18454}
# {'dm': 0, 'vector_size': 300, 'window': 10, 'epochs': 20, 'score': 17563}
# {'dm': 0, 'vector_size': 300, 'window': 10, 'epochs': 30, 'score': 16757}
# {'dm': 0, 'vector_size': 400, 'window': 3, 'epochs': 10, 'score': 18694}
# {'dm': 0, 'vector_size': 400, 'window': 3, 'epochs': 20, 'score': 17709}
# {'dm': 0, 'vector_size': 400, 'window': 3, 'epochs': 30, 'score': 16852}
# {'dm': 0, 'vector_size': 400, 'window': 5, 'epochs': 10, 'score': 18633}
# {'dm': 0, 'vector_size': 400, 'window': 5, 'epochs': 20, 'score': 17547}
# {'dm': 0, 'vector_size': 400, 'window': 5, 'epochs': 30, 'score': 16811}
# {'dm': 0, 'vector_size': 400, 'window': 10, 'epochs': 10, 'score': 18644}
# {'dm': 0, 'vector_size': 400, 'window': 10, 'epochs': 20, 'score': 17663}
# {'dm': 0, 'vector_size': 400, 'window': 10, 'epochs': 30, 'score': 16856}
# {'dm': 0, 'vector_size': 500, 'window': 3, 'epochs': 10, 'score': 18509}
# {'dm': 0, 'vector_size': 500, 'window': 3, 'epochs': 20, 'score': 17607}
# {'dm': 0, 'vector_size': 500, 'window': 3, 'epochs': 30, 'score': 16883}
# {'dm': 0, 'vector_size': 500, 'window': 5, 'epochs': 10, 'score': 18769}
# {'dm': 0, 'vector_size': 500, 'window': 5, 'epochs': 20, 'score': 17575}
# {'dm': 0, 'vector_size': 500, 'window': 5, 'epochs': 30, 'score': 16814}
# {'dm': 0, 'vector_size': 500, 'window': 10, 'epochs': 10, 'score': 18709}
# {'dm': 0, 'vector_size': 500, 'window': 10, 'epochs': 20, 'score': 17676}
# {'dm': 0, 'vector_size': 500, 'window': 10, 'epochs': 30, 'score': 16794}
# {'dm': 0, 'vector_size': 600, 'window': 3, 'epochs': 10, 'score': 18681}
# {'dm': 0, 'vector_size': 600, 'window': 3, 'epochs': 20, 'score': 17648}
# {'dm': 0, 'vector_size': 600, 'window': 3, 'epochs': 30, 'score': 16644}
# {'dm': 0, 'vector_size': 600, 'window': 5, 'epochs': 10, 'score': 18722}
# {'dm': 0, 'vector_size': 600, 'window': 5, 'epochs': 20, 'score': 17626}
# {'dm': 0, 'vector_size': 600, 'window': 5, 'epochs': 30, 'score': 16733}
# {'dm': 0, 'vector_size': 600, 'window': 10, 'epochs': 10, 'score': 18506}
# {'dm': 0, 'vector_size': 600, 'window': 10, 'epochs': 20, 'score': 17634}
# {'dm': 0, 'vector_size': 600, 'window': 10, 'epochs': 30, 'score': 16765}
# {'dm': 0, 'vector_size': 700, 'window': 3, 'epochs': 10, 'score': 18521}
# {'dm': 0, 'vector_size': 700, 'window': 3, 'epochs': 20, 'score': 17634}
# {'dm': 0, 'vector_size': 700, 'window': 3, 'epochs': 30, 'score': 16862}
# {'dm': 0, 'vector_size': 700, 'window': 5, 'epochs': 10, 'score': 18571}
# {'dm': 0, 'vector_size': 700, 'window': 5, 'epochs': 20, 'score': 17713}
# {'dm': 0, 'vector_size': 700, 'window': 5, 'epochs': 30, 'score': 16782}
# {'dm': 0, 'vector_size': 700, 'window': 10, 'epochs': 10, 'score': 18514}
# {'dm': 0, 'vector_size': 700, 'window': 10, 'epochs': 20, 'score': 17630}
# {'dm': 0, 'vector_size': 700, 'window': 10, 'epochs': 30, 'score': 16798}
# {'dm': 1, 'vector_size': 200, 'window': 3, 'epochs': 10, 'score': 16032}
# {'dm': 1, 'vector_size': 200, 'window': 3, 'epochs': 20, 'score': 17056}
# {'dm': 1, 'vector_size': 200, 'window': 3, 'epochs': 30, 'score': 16893}
# {'dm': 1, 'vector_size': 200, 'window': 5, 'epochs': 10, 'score': 15523}
# {'dm': 1, 'vector_size': 200, 'window': 5, 'epochs': 20, 'score': 16362}
# {'dm': 1, 'vector_size': 200, 'window': 5, 'epochs': 30, 'score': 16371}
# {'dm': 1, 'vector_size': 200, 'window': 10, 'epochs': 10, 'score': 14993}
# {'dm': 1, 'vector_size': 200, 'window': 10, 'epochs': 20, 'score': 15365}
# {'dm': 1, 'vector_size': 200, 'window': 10, 'epochs': 30, 'score': 14838}
# {'dm': 1, 'vector_size': 300, 'window': 3, 'epochs': 10, 'score': 15966}
# {'dm': 1, 'vector_size': 300, 'window': 3, 'epochs': 20, 'score': 17100}
# {'dm': 1, 'vector_size': 300, 'window': 3, 'epochs': 30, 'score': 16973}
# {'dm': 1, 'vector_size': 300, 'window': 5, 'epochs': 10, 'score': 15908}
# {'dm': 1, 'vector_size': 300, 'window': 5, 'epochs': 20, 'score': 16356}
# {'dm': 1, 'vector_size': 300, 'window': 5, 'epochs': 30, 'score': 16194}
# {'dm': 1, 'vector_size': 300, 'window': 10, 'epochs': 10, 'score': 15411}
# {'dm': 1, 'vector_size': 300, 'window': 10, 'epochs': 20, 'score': 15503}
# {'dm': 1, 'vector_size': 300, 'window': 10, 'epochs': 30, 'score': 14880}
# {'dm': 1, 'vector_size': 400, 'window': 3, 'epochs': 10, 'score': 15743}
# {'dm': 1, 'vector_size': 400, 'window': 3, 'epochs': 20, 'score': 16904}
# {'dm': 1, 'vector_size': 400, 'window': 3, 'epochs': 30, 'score': 16938}
# {'dm': 1, 'vector_size': 400, 'window': 5, 'epochs': 10, 'score': 15532}
# {'dm': 1, 'vector_size': 400, 'window': 5, 'epochs': 20, 'score': 16302}
# {'dm': 1, 'vector_size': 400, 'window': 5, 'epochs': 30, 'score': 16196}
# {'dm': 1, 'vector_size': 400, 'window': 10, 'epochs': 10, 'score': 15277}
# {'dm': 1, 'vector_size': 400, 'window': 10, 'epochs': 20, 'score': 15460}
# {'dm': 1, 'vector_size': 400, 'window': 10, 'epochs': 30, 'score': 15082}
# {'dm': 1, 'vector_size': 500, 'window': 3, 'epochs': 10, 'score': 15750}
# {'dm': 1, 'vector_size': 500, 'window': 3, 'epochs': 20, 'score': 17167}
# {'dm': 1, 'vector_size': 500, 'window': 3, 'epochs': 30, 'score': 16989}
# {'dm': 1, 'vector_size': 500, 'window': 5, 'epochs': 10, 'score': 15836}
# {'dm': 1, 'vector_size': 500, 'window': 5, 'epochs': 20, 'score': 16512}
# {'dm': 1, 'vector_size': 500, 'window': 5, 'epochs': 30, 'score': 16319}
# {'dm': 1, 'vector_size': 500, 'window': 10, 'epochs': 10, 'score': 15381}
# {'dm': 1, 'vector_size': 500, 'window': 10, 'epochs': 20, 'score': 15577}
# {'dm': 1, 'vector_size': 500, 'window': 10, 'epochs': 30, 'score': 14983}
# {'dm': 1, 'vector_size': 600, 'window': 3, 'epochs': 10, 'score': 15964}
# {'dm': 1, 'vector_size': 600, 'window': 3, 'epochs': 20, 'score': 17077}
# {'dm': 1, 'vector_size': 600, 'window': 3, 'epochs': 30, 'score': 16922}
# {'dm': 1, 'vector_size': 600, 'window': 5, 'epochs': 10, 'score': 15520}
# {'dm': 1, 'vector_size': 600, 'window': 5, 'epochs': 20, 'score': 16503}
# {'dm': 1, 'vector_size': 600, 'window': 5, 'epochs': 30, 'score': 16231}
# {'dm': 1, 'vector_size': 600, 'window': 10, 'epochs': 10, 'score': 15207}
# {'dm': 1, 'vector_size': 600, 'window': 10, 'epochs': 20, 'score': 15525}
# {'dm': 1, 'vector_size': 600, 'window': 10, 'epochs': 30, 'score': 14984}
# {'dm': 1, 'vector_size': 700, 'window': 3, 'epochs': 10, 'score': 15705}
# {'dm': 1, 'vector_size': 700, 'window': 3, 'epochs': 20, 'score': 16990}
# {'dm': 1, 'vector_size': 700, 'window': 3, 'epochs': 30, 'score': 16959}
# {'dm': 1, 'vector_size': 700, 'window': 5, 'epochs': 10, 'score': 15599}
# {'dm': 1, 'vector_size': 700, 'window': 5, 'epochs': 20, 'score': 16432}
# {'dm': 1, 'vector_size': 700, 'window': 5, 'epochs': 30, 'score': 16492}
# {'dm': 1, 'vector_size': 700, 'window': 10, 'epochs': 10, 'score': 15241}
# {'dm': 1, 'vector_size': 700, 'window': 10, 'epochs': 20, 'score': 15349}
# {'dm': 1, 'vector_size': 700, 'window': 10, 'epochs': 30, 'score': 14853}
#      dm  vector_size  window  epochs  score
# 30    0          500       5      10  18769
# 39    0          600       5      10  18722
# 33    0          500      10      10  18709
# 18    0          400       3      10  18694
# 36    0          600       3      10  18681
# ..   ..          ...     ...     ...    ...
# 98    1          600      10      30  14984
# 89    1          500      10      30  14983
# 71    1          300      10      30  14880
# 107   1          700      10      30  14853
# 62    1          200      10      30  14838
#
# [108 rows x 5 columns]

# %%
scoreList.to_csv('./jd_tuning.csv')
