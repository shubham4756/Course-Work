# %%
# !pip install -U gensim
# Out:
# ^C

# %%
import pandas as pd
import numpy as np
import gensim
from sklearn.linear_model import LogisticRegression
from gensim.models.doc2vec import TaggedDocument
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.svm import SVC
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from gensim.models import Doc2Vec
import multiprocessing
from sklearn import utils
from sklearn.model_selection import train_test_split
from gensim.parsing.preprocessing import remove_stopwords
from gensim.utils import simple_preprocess
from gensim.parsing.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
import nltk

import itertools
from gensim.similarities import MatrixSimilarity
from gensim.parsing.preprocessing import preprocess_documents
from gensim.parsing.preprocessing import preprocess_string

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
resumeDf = pd.read_csv("Resume.csv")
resumeDf
# Out:
#       id            category  \
# 0      1  software developer
# 1      2  software developer
# 2      3  software developer
# 3      4  software developer
# 4      5  software developer
# ..   ...                 ...
# 436  545      java developer
# 437  546      java developer
# 438  547      java developer
# 439  548      java developer
# 440  549      java developer
#
#                                                 resume
# 0             SOFTWARE  DEVELOPER  INTERN          ...
# 1             SOFTWARE DEVELOPER       Professional...
# 2             GIS ANALYST/SOFTWARE DEVELOPER       ...
# 3             SENIOR SOFTWARE DEVELOPER       Caree...
# 4             SENIOR SOFTWARE DEVELOPER       Summa...
# ..                                                 ...
# 436           GRADUATE RESEARCH ASSISTANT       Pro...
# 437           GRADUATE RESEARCH ASSISTANT          ...
# 438           STUDENT ASSISTANT         Qualificati...
# 439          YW         TEAM LEAD       Summary    ...
# 440           SENIOR APPLICATION ADMINISTRATOR & SO...
#
# [441 rows x 3 columns]

# %%
def clean(text):
    text = re.sub('http\S+\s*', ' ', text)  # remove URLs
    text = re.sub('RT|cc', ' ', text)  # remove RT and cc
    text = re.sub('#\S+', '', text)  # remove hashtags
    text = re.sub('@\S+', '  ', text)  # remove mentions
    text = re.sub('[%s]' % re.escape("""!"$%&'()*,-/:;<=>?@[\]^_`{|}~"""), ' ', text)  # remove punctuations
    text = re.sub(r'[^\x00-\x7f]',r' ', text) 
    text = re.sub('\s+', ' ', text)  # remove extra whitespace
    return text

# %%
resumeDf['cleaned_resume'] = ""

#cleaning data
resumeDf['cleaned_resume'] = resumeDf.resume.apply(lambda x: clean(x))

# Removing the stop words
resumeDf['cleaned_resume'] = resumeDf.cleaned_resume.apply(lambda x: remove_stopwords(x))

# Tokenize the text column
resumeDf['cleaned_resume'] = [simple_preprocess(line, deacc=True) for line in resumeDf['cleaned_resume']] 

# Get the stemmed_tokens
porter_stemmer = PorterStemmer()
resumeDf['cleaned_resume'] = [[porter_stemmer.stem(word) for word in tokens] for tokens in resumeDf['cleaned_resume'] ]

# get the lammatized tokens
lemmatizer = WordNetLemmatizer() 
resumeDf['cleaned_resume'] = [[lemmatizer.lemmatize(word) for word in tokens] for tokens in resumeDf['cleaned_resume'] ]

# %%
resumeDf
# Out:
#       id            category  \
# 0      1  software developer
# 1      2  software developer
# 2      3  software developer
# 3      4  software developer
# 4      5  software developer
# ..   ...                 ...
# 436  545      java developer
# 437  546      java developer
# 438  547      java developer
# 439  548      java developer
# 440  549      java developer
#
#                                                 resume  \
# 0             SOFTWARE  DEVELOPER  INTERN          ...
# 1             SOFTWARE DEVELOPER       Professional...
# 2             GIS ANALYST/SOFTWARE DEVELOPER       ...
# 3             SENIOR SOFTWARE DEVELOPER       Caree...
# 4             SENIOR SOFTWARE DEVELOPER       Summa...
# ..                                                 ...
# 436           GRADUATE RESEARCH ASSISTANT       Pro...
# 437           GRADUATE RESEARCH ASSISTANT          ...
# 438           STUDENT ASSISTANT         Qualificati...
# 439          YW         TEAM LEAD       Summary    ...
# 440           SENIOR APPLICATION ADMINISTRATOR & SO...
#
#                                         cleaned_resume
# 0    [softwar, develop, intern, summari, skill, pro...
# 1    [softwar, develop, profession, summari, to, ob...
# 2    [gi, analyst, softwar, develop, summari, to, c...
# 3    [senior, softwar, develop, career, focu, to, w...
# 4    [senior, softwar, develop, summari, oracl, cer...
# ..                                                 ...
# 436  [graduat, research, assist, profession, profil...
# 437  [graduat, research, assist, summari, to, obtai...
# 438  [student, assist, qualif, algorithm, java, sof...
# 439  [yw, team, lead, summari, motiv, team, lead, p...
# 440  [senior, applic, administr, solut, architect, ...
#
# [441 rows x 4 columns]

# %%
dm = [0, 1]
vector_size = [200, 300, 400, 500, 600, 700]
window = [3, 5, 10]
epochs = [10, 20, 30]
paramsList = [{'dm': item[0],
               'vector_size': item[1],
               'window': item[2],
               'epochs' : item[3],
               } for item in
                 list(itertools.product(*[dm,
                                          vector_size,
                                          window,
                                          epochs]))
              ]

# %%
def evaluation_doc2vec(params, processed_corpus, top=10):
    tagged_corpus = [TaggedDocument(d, [i]) for i, d in enumerate(processed_corpus)]
    scoreList = []
    for param in params:
        param['score'] = 0
        model = None
        try:
            model = Doc2Vec(tagged_corpus,
                          dm=param['dm'], 
                          vector_size=param['vector_size'], 
                          window=param['window'], 
                          min_count=1, 
                          epochs=param['epochs'], 
                          hs=1)
            for i in range(len(resumeDf)):
                new_doc = resumeDf['cleaned_resume'][i]
                test_doc_vector = model.infer_vector(new_doc)
                sims=model.docvecs.most_similar(positive=[test_doc_vector])
                topSims = sims[:10]
                for ii in range(len(topSims)):
                    if (resumeDf['category'][i]) == (resumeDf['category'][topSims[ii][0]]):
                        param['score'] = param['score'] + (top - ii)
            print(param)
            scoreList.append(param)
        except Exception as error:
            print(f'Cannot evaluate model with parameters {param} because of error: {error}')
            continue
    return scoreList

# %%
scoreList = evaluation_doc2vec(paramsList ,resumeDf['cleaned_resume'].values)
scoreList = pd.DataFrame(scoreList)
scoreList = scoreList.sort_values(by = ['score'], ascending = False)
print(scoreList)
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_4200/195662707.py:18: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   sims=model.docvecs.most_similar(positive=[test_doc_vector])
# {'dm': 0, 'vector_size': 200, 'window': 3, 'epochs': 10, 'score': 13600}
# {'dm': 0, 'vector_size': 200, 'window': 3, 'epochs': 20, 'score': 12822}
# {'dm': 0, 'vector_size': 200, 'window': 3, 'epochs': 30, 'score': 12505}
# {'dm': 0, 'vector_size': 200, 'window': 5, 'epochs': 10, 'score': 13717}
# {'dm': 0, 'vector_size': 200, 'window': 5, 'epochs': 20, 'score': 12787}
# {'dm': 0, 'vector_size': 200, 'window': 5, 'epochs': 30, 'score': 12473}
# {'dm': 0, 'vector_size': 200, 'window': 10, 'epochs': 10, 'score': 13700}
# {'dm': 0, 'vector_size': 200, 'window': 10, 'epochs': 20, 'score': 12793}
# {'dm': 0, 'vector_size': 200, 'window': 10, 'epochs': 30, 'score': 12562}
# {'dm': 0, 'vector_size': 300, 'window': 3, 'epochs': 10, 'score': 13592}
# {'dm': 0, 'vector_size': 300, 'window': 3, 'epochs': 20, 'score': 12923}
# {'dm': 0, 'vector_size': 300, 'window': 3, 'epochs': 30, 'score': 12770}
# {'dm': 0, 'vector_size': 300, 'window': 5, 'epochs': 10, 'score': 13668}
# {'dm': 0, 'vector_size': 300, 'window': 5, 'epochs': 20, 'score': 12830}
# {'dm': 0, 'vector_size': 300, 'window': 5, 'epochs': 30, 'score': 12737}
# {'dm': 0, 'vector_size': 300, 'window': 10, 'epochs': 10, 'score': 13644}
# {'dm': 0, 'vector_size': 300, 'window': 10, 'epochs': 20, 'score': 12850}
# {'dm': 0, 'vector_size': 300, 'window': 10, 'epochs': 30, 'score': 12722}
# {'dm': 0, 'vector_size': 400, 'window': 3, 'epochs': 10, 'score': 13619}
# {'dm': 0, 'vector_size': 400, 'window': 3, 'epochs': 20, 'score': 12840}
# {'dm': 0, 'vector_size': 400, 'window': 3, 'epochs': 30, 'score': 12731}
# {'dm': 0, 'vector_size': 400, 'window': 5, 'epochs': 10, 'score': 13611}
# {'dm': 0, 'vector_size': 400, 'window': 5, 'epochs': 20, 'score': 12840}
# {'dm': 0, 'vector_size': 400, 'window': 5, 'epochs': 30, 'score': 12781}
# {'dm': 0, 'vector_size': 400, 'window': 10, 'epochs': 10, 'score': 13692}
# {'dm': 0, 'vector_size': 400, 'window': 10, 'epochs': 20, 'score': 12891}
# {'dm': 0, 'vector_size': 400, 'window': 10, 'epochs': 30, 'score': 12786}
# {'dm': 0, 'vector_size': 500, 'window': 3, 'epochs': 10, 'score': 13698}
# {'dm': 0, 'vector_size': 500, 'window': 3, 'epochs': 20, 'score': 12854}
# {'dm': 0, 'vector_size': 500, 'window': 3, 'epochs': 30, 'score': 12769}
# {'dm': 0, 'vector_size': 500, 'window': 5, 'epochs': 10, 'score': 13656}
# {'dm': 0, 'vector_size': 500, 'window': 5, 'epochs': 20, 'score': 12842}
# {'dm': 0, 'vector_size': 500, 'window': 5, 'epochs': 30, 'score': 12776}
# {'dm': 0, 'vector_size': 500, 'window': 10, 'epochs': 10, 'score': 13617}
# {'dm': 0, 'vector_size': 500, 'window': 10, 'epochs': 20, 'score': 12917}
# {'dm': 0, 'vector_size': 500, 'window': 10, 'epochs': 30, 'score': 12806}
# {'dm': 0, 'vector_size': 600, 'window': 3, 'epochs': 10, 'score': 13681}
# {'dm': 0, 'vector_size': 600, 'window': 3, 'epochs': 20, 'score': 12903}
# {'dm': 0, 'vector_size': 600, 'window': 3, 'epochs': 30, 'score': 12716}
# {'dm': 0, 'vector_size': 600, 'window': 5, 'epochs': 10, 'score': 13667}
# {'dm': 0, 'vector_size': 600, 'window': 5, 'epochs': 20, 'score': 12870}
# {'dm': 0, 'vector_size': 600, 'window': 5, 'epochs': 30, 'score': 12776}
# {'dm': 0, 'vector_size': 600, 'window': 10, 'epochs': 10, 'score': 13538}
# {'dm': 0, 'vector_size': 600, 'window': 10, 'epochs': 20, 'score': 12961}
# {'dm': 0, 'vector_size': 600, 'window': 10, 'epochs': 30, 'score': 12821}
# {'dm': 0, 'vector_size': 700, 'window': 3, 'epochs': 10, 'score': 13603}
# {'dm': 0, 'vector_size': 700, 'window': 3, 'epochs': 20, 'score': 12938}
# {'dm': 0, 'vector_size': 700, 'window': 3, 'epochs': 30, 'score': 12781}
# {'dm': 0, 'vector_size': 700, 'window': 5, 'epochs': 10, 'score': 13617}
# {'dm': 0, 'vector_size': 700, 'window': 5, 'epochs': 20, 'score': 12840}
# {'dm': 0, 'vector_size': 700, 'window': 5, 'epochs': 30, 'score': 12805}
# {'dm': 0, 'vector_size': 700, 'window': 10, 'epochs': 10, 'score': 13644}
# {'dm': 0, 'vector_size': 700, 'window': 10, 'epochs': 20, 'score': 12862}
# {'dm': 0, 'vector_size': 700, 'window': 10, 'epochs': 30, 'score': 12771}
# {'dm': 1, 'vector_size': 200, 'window': 3, 'epochs': 10, 'score': 13232}
# {'dm': 1, 'vector_size': 200, 'window': 3, 'epochs': 20, 'score': 13596}
# {'dm': 1, 'vector_size': 200, 'window': 3, 'epochs': 30, 'score': 13675}
# {'dm': 1, 'vector_size': 200, 'window': 5, 'epochs': 10, 'score': 12705}
# {'dm': 1, 'vector_size': 200, 'window': 5, 'epochs': 20, 'score': 13285}
# {'dm': 1, 'vector_size': 200, 'window': 5, 'epochs': 30, 'score': 13297}
# {'dm': 1, 'vector_size': 200, 'window': 10, 'epochs': 10, 'score': 12241}
# {'dm': 1, 'vector_size': 200, 'window': 10, 'epochs': 20, 'score': 12368}
# {'dm': 1, 'vector_size': 200, 'window': 10, 'epochs': 30, 'score': 12536}
# {'dm': 1, 'vector_size': 300, 'window': 3, 'epochs': 10, 'score': 13269}
# {'dm': 1, 'vector_size': 300, 'window': 3, 'epochs': 20, 'score': 13627}
# {'dm': 1, 'vector_size': 300, 'window': 3, 'epochs': 30, 'score': 13653}
# {'dm': 1, 'vector_size': 300, 'window': 5, 'epochs': 10, 'score': 12792}
# {'dm': 1, 'vector_size': 300, 'window': 5, 'epochs': 20, 'score': 13209}
# {'dm': 1, 'vector_size': 300, 'window': 5, 'epochs': 30, 'score': 13495}
# {'dm': 1, 'vector_size': 300, 'window': 10, 'epochs': 10, 'score': 12339}
# {'dm': 1, 'vector_size': 300, 'window': 10, 'epochs': 20, 'score': 12572}
# {'dm': 1, 'vector_size': 300, 'window': 10, 'epochs': 30, 'score': 12604}
# {'dm': 1, 'vector_size': 400, 'window': 3, 'epochs': 10, 'score': 13205}
# {'dm': 1, 'vector_size': 400, 'window': 3, 'epochs': 20, 'score': 13509}
# {'dm': 1, 'vector_size': 400, 'window': 3, 'epochs': 30, 'score': 13613}
# {'dm': 1, 'vector_size': 400, 'window': 5, 'epochs': 10, 'score': 12816}
# {'dm': 1, 'vector_size': 400, 'window': 5, 'epochs': 20, 'score': 13328}
# {'dm': 1, 'vector_size': 400, 'window': 5, 'epochs': 30, 'score': 13296}
# {'dm': 1, 'vector_size': 400, 'window': 10, 'epochs': 10, 'score': 12446}
# {'dm': 1, 'vector_size': 400, 'window': 10, 'epochs': 20, 'score': 12452}
# {'dm': 1, 'vector_size': 400, 'window': 10, 'epochs': 30, 'score': 12627}
# {'dm': 1, 'vector_size': 500, 'window': 3, 'epochs': 10, 'score': 13145}
# {'dm': 1, 'vector_size': 500, 'window': 3, 'epochs': 20, 'score': 13553}
# {'dm': 1, 'vector_size': 500, 'window': 3, 'epochs': 30, 'score': 13712}
# {'dm': 1, 'vector_size': 500, 'window': 5, 'epochs': 10, 'score': 12887}
# {'dm': 1, 'vector_size': 500, 'window': 5, 'epochs': 20, 'score': 13324}
# {'dm': 1, 'vector_size': 500, 'window': 5, 'epochs': 30, 'score': 13380}
# {'dm': 1, 'vector_size': 500, 'window': 10, 'epochs': 10, 'score': 12412}
# {'dm': 1, 'vector_size': 500, 'window': 10, 'epochs': 20, 'score': 12584}
# {'dm': 1, 'vector_size': 500, 'window': 10, 'epochs': 30, 'score': 12614}
# {'dm': 1, 'vector_size': 600, 'window': 3, 'epochs': 10, 'score': 13175}
# {'dm': 1, 'vector_size': 600, 'window': 3, 'epochs': 20, 'score': 13603}
# {'dm': 1, 'vector_size': 600, 'window': 3, 'epochs': 30, 'score': 13680}
# {'dm': 1, 'vector_size': 600, 'window': 5, 'epochs': 10, 'score': 12794}
# {'dm': 1, 'vector_size': 600, 'window': 5, 'epochs': 20, 'score': 13340}
# {'dm': 1, 'vector_size': 600, 'window': 5, 'epochs': 30, 'score': 13386}
# {'dm': 1, 'vector_size': 600, 'window': 10, 'epochs': 10, 'score': 12147}
# {'dm': 1, 'vector_size': 600, 'window': 10, 'epochs': 20, 'score': 12546}
# {'dm': 1, 'vector_size': 600, 'window': 10, 'epochs': 30, 'score': 12597}
# {'dm': 1, 'vector_size': 700, 'window': 3, 'epochs': 10, 'score': 13167}
# {'dm': 1, 'vector_size': 700, 'window': 3, 'epochs': 20, 'score': 13509}
# {'dm': 1, 'vector_size': 700, 'window': 3, 'epochs': 30, 'score': 13523}
# {'dm': 1, 'vector_size': 700, 'window': 5, 'epochs': 10, 'score': 12807}
# {'dm': 1, 'vector_size': 700, 'window': 5, 'epochs': 20, 'score': 13201}
# {'dm': 1, 'vector_size': 700, 'window': 5, 'epochs': 30, 'score': 13397}
# {'dm': 1, 'vector_size': 700, 'window': 10, 'epochs': 10, 'score': 12280}
# {'dm': 1, 'vector_size': 700, 'window': 10, 'epochs': 20, 'score': 12492}
# {'dm': 1, 'vector_size': 700, 'window': 10, 'epochs': 30, 'score': 12716}
#      dm  vector_size  window  epochs  score
# 3     0          200       5      10  13717
# 83    1          500       3      30  13712
# 6     0          200      10      10  13700
# 27    0          500       3      10  13698
# 24    0          400      10      10  13692
# ..   ..          ...     ...     ...    ...
# 61    1          200      10      20  12368
# 69    1          300      10      10  12339
# 105   1          700      10      10  12280
# 60    1          200      10      10  12241
# 96    1          600      10      10  12147
#
# [108 rows x 5 columns]

# %%
scoreList.to_csv('./resume_tuning.csv')
